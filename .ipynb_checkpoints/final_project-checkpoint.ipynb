# %%
# %pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import statement
import pandas as pd
import numpy as np
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats

nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('stopwords')

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/sicilywang/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/sicilywang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sicilywang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## A statement of the problem you are investigating (WIP)

# %% [markdown]
# ## Why is this problem relevant? Or, what inspired you to investigate this problem (WIP)

# %% [markdown]
# ## Read data

# %%
vlog = pd.read_csv('vlog.csv')

# %%
vlog.head(5)
# Out:
#            username            author_id  \
# 0    MagicalAquatic  7140140605107127342
# 1              jah✰  6961499315445482501
# 2  Caroline Collins  6776019851430560774
# 3    🦞Craw Kingdom👑  6835639642319193094
# 4       Cassie Aran  6747490126719206405
#
#                                           video_desc             video_id  \
# 0  Another use for 360 cam #ocean #sea #vlog #tra...  7143031687490882858
# 1  imma still try to keep em daily… #LikeAMonarch...  7144924903270108462
# 2  From 2:45 AM to 4:59 AM ☕️ This is my Monday t...  7138820984827612459
# 3  😩 IM HAPPY NOW!!!! #chicharron #Mexican #somex...  7139230020718906666
# 4  HURRICANE IS GETTING WORSE😳 #daywithme #vlog #...  7147887060324584747
#
#    upload_time  duration             was_duet  \
# 0   1663116673        20  {'duetFromId': '0'}
# 1   1663557479        37  {'duetFromId': '0'}
# 2   1662136289        78  {'duetFromId': '0'}
# 3   1662231523        57  {'duetFromId': '0'}
# ...

# %% [markdown]
# ## Basic info

# %%
vlog.shape
# Out:
# (999, 20)

# %%
vlog.dtypes
# Out:
# username              object
# author_id              int64
# video_desc            object
# video_id               int64
# upload_time            int64
# duration               int64
# was_duet              object
# hashtags              object
# music_artist          object
# music_title           object
# is_verified             bool
# author_followers       int64
# author_likes           int64
# author_hearts          int64
# author_video_count     int64
# saves                  int64
# likes                  int64
# shares                 int64
# plays                  int64
# comments               int64
# dtype: object

# %%
vlog.describe()
# Out:
#           author_id      video_id   upload_time    duration  author_followers  \
# count  9.990000e+02  9.990000e+02  9.990000e+02  999.000000      9.990000e+02
# mean   5.587109e+18  7.111583e+18  1.660123e+09   71.123123      2.603743e+06
# std    2.671875e+18  4.059729e+17  3.459084e+07   60.975716      4.934415e+06
# min    1.431400e+04  1.091123e+17  1.466357e+09    0.000000      0.000000e+00
# 25%    6.585407e+18  7.046933e+18  1.640742e+09   30.000000      2.175500e+05
# 50%    6.781315e+18  7.153473e+18  1.665548e+09   57.000000      9.205000e+05
# 75%    6.969483e+18  7.240934e+18  1.685911e+09   90.000000      3.050000e+06
# max    7.318645e+18  7.357814e+18  1.713125e+09  441.000000      5.440000e+07
#
#         author_likes  author_hearts  author_video_count          saves  \
# count     999.000000   9.990000e+02          999.000000     999.000000
# mean    27191.977978   1.298660e+08          896.934935   66392.746747
# ...

# %% [markdown]
# ## Where did you get the data from? (WIP)

# %% [markdown]
# ## Description of the data (WIP)

# %% [markdown]
# ## Data Cleaning

# %%
vlog = vlog.fillna('')

# %%
# Cleaning all the special characters and emojis
emoji_pattern = re.compile("["
         u"\U0001F600-\U0001F64F"  # emoticons
         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
         u"\U0001F680-\U0001F6FF"  # transport & map symbols
         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
         u"\U0001F900-\U0001F9FF"  # supplementary symbols and pictographs
         u"\U0001FA70-\U0001FAFF"  # symbols and pictographs extended-A
         u"\U00002702-\U000027B0"  # Dingbats
         u"\U000024C2-\U0001F251" 
         "]+", flags=re.UNICODE) # The UNICODE pattern is generated by ChatGPT to detect emojis

for column in vlog.select_dtypes(include=['object']):
    vlog[column] = vlog[column].apply(lambda x: emoji_pattern.sub(r'', str(x)) if x else x)
# tokenize the video_desc with stop words
stop_words = set(stopwords.words('english'))

# %%
def tokenize_without_stopwords_and_symbols(text):
    tokens = word_tokenize(text.lower())
    filtered_tokens = [word for word in tokens if word not in stop_words and re.match('^[a-zA-Z0-9]+$', word)]
    return filtered_tokens
def convert_to_list(hashtag_str):
    hashtags = hashtag_str.strip("[]").split("', '")
    hashtags = [tag.strip("'") for tag in hashtags if tag != '' and tag != "''" and tag != ","]
    return hashtags

vlog['hashtags'] = vlog['hashtags'].apply(convert_to_list)
vlog['video_desc'] = vlog['video_desc'].apply(tokenize_without_stopwords_and_symbols)

# transforming the upload_time to pd.datetime
vlog['upload_time'] = pd.to_datetime(vlog['upload_time'], unit= 's')

# %%
sia = SentimentIntensityAnalyzer()
vlog['video_desc_str'] = vlog['video_desc'].apply(' '.join)

# Define a function to get sentiment score
def get_sentiment_score(text):
    return sia.polarity_scores(text)['compound']

# Apply the function to the string version of video_desc
vlog['sentiment_score'] = vlog['video_desc_str'].apply(get_sentiment_score)

def transfer_to_cate(score):
#     if score < -0.25:
#         return -1
#     if score > 0.25:
#         return 1
#     return 0
    if abs(score) < 0.25:
        return 0
    return 1
vlog['sentiment_binary'] = vlog['sentiment_score'].apply(transfer_to_cate)

# %%
vlog = vlog.drop(columns = ['was_duet', 'music_artist', 'is_verified', 'author_likes', 'author_hearts', 'music_title','sentiment_score', 'video_desc_str'])

# %%
vlog.head(5)
# Out:
#            username            author_id  \
# 0    MagicalAquatic  7140140605107127342
# 1               jah  6961499315445482501
# 2  Caroline Collins  6776019851430560774
# 3      Craw Kingdom  6835639642319193094
# 4       Cassie Aran  6747490126719206405
#
#                                           video_desc             video_id  \
# 0  [another, use, 360, cam, ocean, sea, vlog, tra...  7143031687490882858
# 1  [imma, still, try, keep, em, likeamonarch, sep...  7144924903270108462
# 2  [monday, friday, mornings, news, anchor, news,...  7138820984827612459
# 3  [im, happy, chicharron, mexican, somexican, fo...  7139230020718906666
# 4  [hurricane, getting, worse, daywithme, vlog, d...  7147887060324584747
#
#           upload_time  duration  \
# 0 2022-09-14 00:51:13        20
# 1 2022-09-19 03:17:59        37
# 2 2022-09-02 16:31:29        78
# 3 2022-09-03 18:58:43        57
# 4 2022-09-27 02:52:31        63
#
# ...

# %% [markdown]
# ## EDA

# %%
#Import lib
# Import seaborn and apply its plotting styles
import seaborn as sns
sns.set(style="white", font_scale = 1.3)

# import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style

import statsmodels.api as sm
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np


# %config InlineBackend.figure_formats = ['svg']
plt.rcParams["figure.figsize"] = [10, 6]

# %% [markdown]
# ### Outliers

# %%
likes = vlog['likes'].to_numpy()
Q1 = np.percentile(likes, 25)
Q3 = np.percentile(likes, 75)

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Calculate the upper bound to identify outliers
upper_bound = Q3 + 1.5 * IQR
vlog = vlog[vlog['likes'] < upper_bound]

# %% [markdown]
# ### Distribution of variables:
# - duration
# - Upload time
# - Sentiment
#
# - video: saves, likes, shares, plays
#
# QQ-plot (eg. likes - normal distribution)

# %%
# Calculate outlier boundary
Q1 = vlog['duration'].quantile(0.25)
Q3 = vlog['duration'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR

# Plot the histogram with KDE
sns.histplot(data=vlog, x='duration', kde=True, bins=50)
plt.xticks(range(0, int(vlog['duration'].max()) + 1, 50))

# Add vertical lines for the outlier boundaries
plt.axvline(x=upper_bound, color='r', linestyle='--', label='Upper Outlier Bound')

# Add titles and labels
plt.title('Distribution of Duration')
plt.xlabel('Duration (seconds)')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# The duration distribution is skewed to the right, mostly around 60 seconds (or 1 minute) and only a few outliers which is higher than 180 seconds (or 3 minutes). This can be interpreted as Tiktok is a short video platform, in which the duration of works released is relatively short.

# %%
# Calculate outlier
upload_times = vlog['upload_time']
Q1 = np.percentile(upload_times, 25)
Q3 = np.percentile(upload_times, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR

# Plot the histogram with KDE
sns.histplot(data=vlog, x='upload_time', kde=True, bins=50)
plt.title('Distribution of Upload Time')
plt.xlabel('Upload Time')
plt.ylabel('Frequency')

# Add vertical lines for outlier boundaries
plt.axvline(x=lower_bound, color='r', linestyle='--', label='Lower Outlier Boundary')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# The distribution of upload times is left-skewed and primarily concentrated around the year 2023. This pattern is expected, as the popularity of 'vlog'-type videos has surged recently, and the dataset concludes with entries up to April, the date we fetch the data. Still, we only have a few outliers that are before year 2020.

# %%
# Drop duplicates based on 'author_id'
vlog_unique = vlog.drop_duplicates(subset='author_id')

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 3))
sns.set(style="white", font_scale=1)

# Plot for number of followers
# Calculate outlier boundary
Q1_followers = np.percentile(vlog_unique['author_followers'], 25)
Q3_followers = np.percentile(vlog_unique['author_followers'], 75)
IQR_followers = Q3_followers - Q1_followers
upper_bound_followers = Q3_followers + 1.5 * IQR_followers

sns.histplot(data=vlog_unique, x='author_followers', kde=True, bins=50, ax=axes[0])
axes[0].set_title('Distribution of Number of Followers', fontsize=15)
axes[0].set_xlabel('Number of Followers', fontsize=12)
axes[0].set_ylabel('Frequency', fontsize=12)
# Add vertical line for outlier boundary
axes[0].axvline(x=upper_bound_followers, color='r', linestyle='--', label='Upper Outlier Boundary')
axes[0].legend()

# Plot for number of videos published
# Calculate outlier boundary
Q1_videos = np.percentile(vlog_unique['author_video_count'], 25)
Q3_videos = np.percentile(vlog_unique['author_video_count'], 75)
IQR_videos = Q3_videos - Q1_videos
upper_bound_videos = Q3_videos + 1.5 * IQR_videos

sns.histplot(data=vlog_unique, x='author_video_count', kde=True, bins=50, ax=axes[1], color='violet')
axes[1].set_title('Distribution of Number of Videos Published', fontsize=15)
axes[1].set_xlabel('Video Count', fontsize=12)
axes[1].set_ylabel('Frequency', fontsize=12)
# Add vertical line for outlier boundary
axes[1].axvline(x=upper_bound_videos, color='r', linestyle='--', label='Upper Outlier Boundary')
axes[1].legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# author_followers
# precentage of outlier
len(vlog_unique[vlog_unique['author_followers']>upper_bound])/len(vlog)

# look at those extreme value
vlog_unique[vlog_unique['author_followers']>20000000]
# Out:
#                  username            author_id  \
# 94                Bayashi  6742459250268832769
# 338          Kira Kosarin             21210630
# 698             BabyAriel               209793
# 753         Coffee Family              7557684
# 828  Jay Prehistoric Pets  6699542567460389894
# 878          Chingu Amiga  6793822572599559173
#
#                                             video_desc             video_id  \
# 94              [kansikskc, vlog, tiktok, daily, life]  6974352292862594305
# 338                                [vlog, thundermans]  7219033991687458094
# 698                [marlins, game, fathers, day, vlog]   109112302938763266
# 753  [today, epic, fun, day, coffeevlog, coffeefami...  6825826586105777414
# 828  [never, boring, zookeeper, zookeeper, vlog, ph...  6848602436802841861
# 878                             [vlog, viaje, ecuador]  7150431351064251653
#
#             upload_time  duration  \
# 94  2021-06-16 11:28:56        59
# ...

# %%
# author_video_count
# precentage of outlier
len(vlog_unique[vlog_unique['author_video_count']>upper_bound])/len(vlog)

# look at those extreme value
vlog_unique[vlog_unique['author_video_count']>5000]
# Out:
#                username            author_id  \
# 463  IdeaTimeEverywhere  6983289086387782661
# 856        Katie Feeney             15251627
#
#                                             video_desc             video_id  \
# 463  [u, like, tank, viral, diyproject, creative, d...  7124595305349172523
# 856  [come, back, part, 3, summervlog, vlog, voiceo...  6851701301252803845
#
#             upload_time  duration  \
# 463 2022-07-26 08:28:39         9
# 856 2020-07-20 23:00:27        41
#
#                                               hashtags  author_followers  \
# 463  [viral, diyproject, creative, diyhomedecor, fi...          15300000
# 856  [summervlog, vlog, voiceover, ivoryella, photo...           7500000
#
#      author_video_count  saves    likes  shares     plays  comments  \
# 463                7169  69000  1100000  109700  26600000     11400
# 856                5789   9108   819200     403   2800000      1058
#
#      sentiment_binary
# 463                 1
# ...

# %% [markdown]
# For 'author_followers' variable, more than half of the video creators have 1 million or fewer followers. However, there are some outliers, comprising roughly 7% of the dataset. Notably, a few values are exceptionally high. For instance, the top author, 'Bayashi', has 54,400,000 followers, which is 1.5 times more than the author with the second highest follower count.
#
# For 'author_video_count' variable, most of the author publish around 500 video, and only a few with higher video.

# %%
fig, axes = plt.subplots(2, 2)
sns.set(style="white", font_scale=1)

# Calculate and plot for saves
Q1_saves = np.percentile(vlog['saves'], 25)
Q3_saves = np.percentile(vlog['saves'], 75)
IQR_saves = Q3_saves - Q1_saves
upper_bound_saves = Q3_saves + 1.5 * IQR_saves

sns.histplot(data=vlog, x='saves', kde=True, bins=50, ax=axes[0][0])
axes[0][0].set_title('Distribution of Saves', fontsize=15)
axes[0][0].set_xlabel('Saves', fontsize=12)
axes[0][0].set_ylabel('Frequency', fontsize=12)
axes[0][0].axvline(x=upper_bound_saves, color='r', linestyle='--', label='Upper Outlier Boundary')
axes[0][0].legend()

# Calculate and plot for plays
Q1_plays = np.percentile(vlog['plays'], 25)
Q3_plays = np.percentile(vlog['plays'], 75)
IQR_plays = Q3_plays - Q1_plays
upper_bound_plays = Q3_plays + 1.5 * IQR_plays

sns.histplot(data=vlog, x='plays', kde=True, bins=50, ax=axes[0][1], color='salmon')
axes[0][1].set_title('Distribution of Plays', fontsize=15)
axes[0][1].set_xlabel('Plays', fontsize=12)
axes[0][1].set_ylabel('Frequency', fontsize=12)
axes[0][1].axvline(x=upper_bound_plays, color='r', linestyle='--', label='Upper Outlier Boundary')
axes[0][1].legend()

# Calculate and plot for shares
Q1_shares = np.percentile(vlog['shares'], 25)
Q3_shares = np.percentile(vlog['shares'], 75)
IQR_shares = Q3_shares - Q1_shares
upper_bound_shares = Q3_shares + 1.5 * IQR_shares

sns.histplot(data=vlog, x='shares', kde=True, bins=50, ax=axes[1][0], color='lightgreen')
axes[1][0].set_title('Distribution of Shares', fontsize=15)
axes[1][0].set_xlabel('Shares', fontsize=12)
axes[1][0].set_ylabel('Frequency', fontsize=12)
axes[1][0].axvline(x=upper_bound_shares, color='r', linestyle='--', label='Upper Outlier Boundary')
axes[1][0].legend()

# Calculate and plot for comments
Q1_comments = np.percentile(vlog['comments'], 25)
Q3_comments = np.percentile(vlog['comments'], 75)
IQR_comments = Q3_comments - Q1_comments
upper_bound_comments = Q3_comments + 1.5 * IQR_comments

sns.histplot(data=vlog, x='comments', kde=True, bins=50, ax=axes[1][1], color='orange')
axes[1][1].set_title('Distribution of Comments', fontsize=15)
axes[1][1].set_xlabel('Comments', fontsize=12)
axes[1][1].set_ylabel('Frequency', fontsize=12)
axes[1][1].axvline(x=upper_bound_comments, color='r', linestyle='--', label='Upper Outlier Boundary')
axes[1][1].legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 'Saves' data is clustered around lower values, likely within the range of 0 to 100,000 saves. There are a few data points with extremely high save counts, extending up to around 400,000 saves, which are outliers.
#
# 'Plays' data is also clustered around lower values, likely within the range of 0 to 1,000,000 plays, with few outliers.
#
# 'Shares' data is mostly in the range of 0 to 50,000 shares. The tail is long, with some videos having shares up to approximately 350,000, suggesting significant outliers.
#
# 'Comments' data is mostly in range of 0 to 10,000 comments. And still exist some outliers.
#
# The variables 'Saves', 'Play', 'Shares', and 'Comments' distributions all with similar shape and are right-skewed, which means that the majority of videos in the dataset have relatively low engagement. But the presence of outliers suggests that a small subset of videos achieves very high engagement. It may be due to factors such as popular creators, or video length, which need to explore further based on their correlation.

# %%
sns.histplot(data = vlog, x = 'likes', kde = True, bins = 50)
plt.show()

# %% [markdown]
# The likes variable is our predicted variable which is also skewed to the right and with some gaps among the number of likes. Also, because we already deleted the outliers before, we no longer need to think about its outliers again. But, we still need to test whether it is normal or not, not just based on visualization.

# %%
# check whether the predicted variable is normal distribution based on qq-plot

# Convert 'likes' column to a numpy array
likes_arr = vlog['likes'].to_numpy()

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 6))

# Normal distribution
normal_dist = stats.norm(np.mean(likes_arr), np.std(likes_arr))
sm.qqplot(likes_arr, normal_dist, line='45', ax=axs[0, 0])
axs[0, 0].set_title('Normal Distribution')

# Exponential distribution
exp_dist = stats.expon(scale=np.mean(likes_arr))
sm.qqplot(likes_arr, exp_dist, line='45', ax=axs[0, 1])
axs[0, 1].set_title('Exponential Distribution')

# Student-t distribution
df, loc, scale = stats.t.fit(likes_arr)
t_dist = stats.t(df, loc, scale)
sm.qqplot(likes_arr, t_dist, line='45', ax=axs[1, 0])
axs[1, 0].set_title('Student-t Distribution')

# log-normal distribution
shape, loc, scale = stats.lognorm.fit(likes_arr, floc=0)
lognorm_dist = stats.lognorm(s=shape, loc=loc, scale=scale)
sm.qqplot(likes_arr, lognorm_dist, line='45', ax=axs[1, 1])
axs[1, 1].set_title('Log-normal Distribution')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Normal Distribution: The QQ plot for the normal distribution shows significant deviation from the straight line, especially in the tails. This suggests that the data does not follow a normal distribution.
#
# Exponential Distribution: The QQ plot for the exponential distribution also shows a substantial deviation from the straight line, particularly in the upper quantiles.
#
# Student-t Distribution: The QQ plot for the Student-t distribution shows some alignment with the line in the middle quantiles but deviates significantly in the tails.
#
# Log-normal Distribution: The QQ plot for the log-normal distribution shows a much better fit compared to the other distributions. The points lie closer to the line, indicating that the sample quantiles align well with the theoretical quantiles of the log-normal distribution. This suggests that the log-normal distribution is a good fit for the data.

# %%
# log transform likes
log_likes_arr = np.log(likes_arr + 1)  # Adding 1 to avoid log(0)

# Fit normal distribution to log-transformed data
log_normal_dist = stats.norm(np.mean(log_likes_arr), np.std(log_likes_arr))

# Create QQ plot
plt.figure(figsize=(10, 6))
sm.qqplot(log_likes_arr, log_normal_dist, line='45')
plt.title('QQ Plot - Log-Transformed Data vs Normal Distribution')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.show()

# %%
# sqrt transform likes
sqrt_likes_arr = np.sqrt(likes_arr)
sqrt_normal_dist = stats.norm(np.mean(sqrt_likes_arr), np.std(sqrt_likes_arr))
plt.figure(figsize=(10, 6))
sm.qqplot(sqrt_likes_arr, sqrt_normal_dist, line='45')
plt.show()

# %% [markdown]
# ### Relation between variables:
#
# heat map
#
# like vs other var

# %%
def log_trans(x):
    return np.log(x + 1)
vlog['log_likes'] = vlog['likes'].apply(log_trans)

# %%
selected_columns = ['duration', 'author_followers', 'author_video_count', 'likes', 'saves', 'plays', 'shares', 'comments','sentiment_binary', 'log_likes']

# Ensure the selected columns are in the DataFrame
vlog_subset = vlog[selected_columns]

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(vlog_subset.corr(), annot=True, cmap='coolwarm')
plt.title('Heatmap of Selected Features')
plt.show()

# %% [markdown]
# The heatmap reveals a strong positive correlation between author_followers and author_video_count, which is reasonable. As authors produce more videos, the audience has more opportunities to watch and follow them. Additionally, there is a notable correlation among saves, plays, shares, and comments, as these metrics collectively indicate video popularity.
#
# However, there are also some unexpected results. Specifically, there is a negative correlation between author_followers and log_like. This counterintuitive finding may be attributable to the presence of confounding variables, which could obscure the true nature of these relationships.

# %%
# sns.pairplot(vlog_subset)
# plt.show()

# %% [markdown]
# ### Outlier analysis

# %% [markdown]
# ## Analysis
